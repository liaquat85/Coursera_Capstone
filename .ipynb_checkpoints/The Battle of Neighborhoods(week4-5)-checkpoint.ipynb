# %% [markdown]
# # The Battle of Neighborhoods- Coursera Capstone Project: Finding a place to open a profitable Afghani resturant
# ## Table of Content
# 1. Introduction: Business Problem
# 2. Data
# 3. Methodology
# 4. Analysis
# 5. Discussion
# 6. Results / Conclusion
#
# ## 1. Introduction: Business Problem
# The final project for the Coursera course: Applied Data Science Capstone of IBM Data Science Professional Certificate is to apply the learning from all the courses of that certificate. In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. In Module 4, we have to come up with an idea of real data science problem and find its solution.
# ### Background information:
# New York is a major metropolitan area with more than 8.4 million (Quick Facts, 2018) people living within city limits. New York City is the largest city in the United States with a long history of international immigration. People came from many parts of the world. According to the 2007 American Community Survey estimates, New York City is home to approximately 50,000 people from Afghanistan. With its diverse culture, comes diverse food items. There are many restaurants in New York City, each belonging to different categories like Chinese, Indian, French, etc. I know that New Yorkers are open to new ideas and food and they would try and taste food from other countries.
# ### Problem statement:
# Long before starting university, I always an idea in my mind to open an authentic Afghani restaurant, especially the afghani bread and kabebs are best. So in this final project, I will work on that idea and try to find the best place in New York City to open an authentic Afghani restaurant.
#
# ### Target audience for this report
# Business personnel who wants to invest or open a restaurant.
#
# Finding the best location for opening a profitable restaurant.
#
# Exploratory Data Analysis techniques to obtain necessary data, analyze it and, finally be able to tell a story out of it.

# %% [markdown]
# ## 2. Data Section
#
# For this project we need the following data:
# 1. New York City data that contains Borough, Neighborhoods along with there latitudes and longitudes
# - Data Source: https://cocl.us/new_york_dataset
# - Description: This data set contains the required information. And we will use this data set to explore various neighborhoods of new york city.
# 2. Afghani restaurants in New York City
# - Data Source: Foursquare API
# - Description: By using this API we will get all the venues in the New York City. We can filter these venues to get only Afghani restaurants.

# %% [markdown]
# ## 3. Methodology
#
# - Collect the new york city data from https://cocl.us/new_york_dataset.
# - Using Foursquare API we will get all venues for each neighborhood.
# - Filter out all venues which are Afghani Restaurants.
# - Data Visualization and some statistical analysis.
# - Analyzing using Clustering (Specially K-Means):
#     1. Find the best value of K
#     2. Visualize the neighborhood with a number of Afghani Restaurants.
# - Compare the Neighborhoods to Find the Best Place for Starting up a Restaurant.
# - Inference From these Results and related Conclusions

# %% [markdown]
# **Before we get the data and start exploring it, let's import all required libraries.**

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# **My Foursquare Credentials and version**

# %%
# Define Foursquare Credentials and Version
# Liaquat Credentials
CLIENT_ID = 'N2OM2D24OZUQSMUMEIGUDHFFEZXIPOESSIX2HYQMS3UTOGGF' # your Foursquare ID
CLIENT_SECRET = '0HL2L0LAJTXZTBWQPI2WZNXQDXEI41FSLUSMTY1EC0UTQ0WC' # your Foursquare Secret
ACCESS_TOKEN = 'M53Q204D2BHSZWJKUBLJBGBDV3JCM5UJ25K51SFM1HZLZ1DX' # your FourSquare Access Token
VERSION = '20180604'

# Ifrah Credentials
# CLIENT_ID = 'TK0DQF3HSC21YNZVEB2DBFHCBQP5CMLS3S0G1MVS0N12LLFQ' # your Foursquare ID
# CLIENT_SECRET = 'IKOOUVRHF5301BUAAHWKU1S5TDX5PGZLP2Q5DBI5VT4FTZUC' # your Foursquare Secret
# ACCESS_TOKEN = 'OEADQWUFDDHO5MAR3M1G1PRBD341POLFZBZ5VOVVTAGJ5XEH' # your FourSquare Access Token
# VERSION = '20180604'

# %% [markdown]
# We will get New York City data such as Borough, Neighborhood along with latitude and longtiude from the website

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data

# %% [markdown]
# Now we will convert that data into Pandas dataframe so that we can apply different anaylsis on the data.

# %%
ny_data = get_new_york_data()
ny_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
ny_data.shape
# Out:
# (306, 4)

# %% [markdown]
# So there are total of 306 different Neighborhoods in New York.

# %% [markdown]
# ## 4. Analysis
#
# Let analyze the initial data.

# %%
clr = "green"
ny_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. Neighborhoods',fontsize = 15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %% [markdown]
# **Let's analyze further and see how many Afghani restaurants there are in each neighborhood and borough. After it, graph the results.**

# %%
def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    #print(url)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
# queens has most neighborhoods
# prepare neighborhood list that contains Afghan restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
afghan_rest_ny=pd.DataFrame(columns=column_names)

count=1
for row in ny_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    afghan_restaurants=venues[venues['Category']=='Afghan Restaurant']   
    print('(',count,'/',len(ny_data),')','Afghan Restaurants in '+Neighborhood+', '+Borough+':'+str(len(afghan_restaurants)))
    print(row)
    for resturant_detail in afghan_restaurants.values.tolist():
        id, name , category=resturant_detail
        afghan_rest_ny = afghan_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) afghan Restaurants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) afghan Restaurants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) afghan Restaurants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) afghan Restaurants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) afghan Restaurants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) afghan Restaurants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) afghan Restaurants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) afghan Restaurants in Woodlawn, Bronx:0
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) afghan Restaurants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) afghan Restaurants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) afghan Restaurants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) afghan Restaurants in Pelham Parkway, Bronx:0
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) afghan Restaurants in City Island, Bronx:0
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) afghan Restaurants in Bedford Park, Bronx:0
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) afghan Restaurants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) afghan Restaurants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) afghan Restaurants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) afghan Restaurants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) afghan Restaurants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) afghan Restaurants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) afghan Restaurants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) afghan Restaurants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) afghan Restaurants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) afghan Restaurants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) afghan Restaurants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) afghan Restaurants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) afghan Restaurants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) afghan Restaurants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) afghan Restaurants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) afghan Restaurants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) afghan Restaurants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) afghan Restaurants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) afghan Restaurants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) afghan Restaurants in Morris Park, Bronx:0
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) afghan Restaurants in Belmont, Bronx:0
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) afghan Restaurants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) afghan Restaurants in North Riverdale, Bronx:0
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) afghan Restaurants in Pelham Bay, Bronx:0
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) afghan Restaurants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) afghan Restaurants in Edgewater Park, Bronx:0
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) afghan Restaurants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) afghan Restaurants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) afghan Restaurants in Pelham Gardens, Bronx:0
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) afghan Restaurants in Concourse, Bronx:0
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) afghan Restaurants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) afghan Restaurants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) afghan Restaurants in Bay Ridge, Brooklyn:0
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) afghan Restaurants in Bensonhurst, Brooklyn:0
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) afghan Restaurants in Sunset Park, Brooklyn:0
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) afghan Restaurants in Greenpoint, Brooklyn:0
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) afghan Restaurants in Gravesend, Brooklyn:0
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) afghan Restaurants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) afghan Restaurants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) afghan Restaurants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) afghan Restaurants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) afghan Restaurants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) afghan Restaurants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) afghan Restaurants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) afghan Restaurants in Windsor Terrace, Brooklyn:0
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) afghan Restaurants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) afghan Restaurants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) afghan Restaurants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) afghan Restaurants in Bushwick, Brooklyn:0
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) afghan Restaurants in Bedford Stuyvesant, Brooklyn:0
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) afghan Restaurants in Brooklyn Heights, Brooklyn:0
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) afghan Restaurants in Cobble Hill, Brooklyn:0
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) afghan Restaurants in Carroll Gardens, Brooklyn:0
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) afghan Restaurants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) afghan Restaurants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) afghan Restaurants in Fort Greene, Brooklyn:0
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) afghan Restaurants in Park Slope, Brooklyn:0
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) afghan Restaurants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) afghan Restaurants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) afghan Restaurants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) afghan Restaurants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) afghan Restaurants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) afghan Restaurants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) afghan Restaurants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) afghan Restaurants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) afghan Restaurants in Bath Beach, Brooklyn:0
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) afghan Restaurants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) afghan Restaurants in Dyker Heights, Brooklyn:0
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) afghan Restaurants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) afghan Restaurants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) afghan Restaurants in Clinton Hill, Brooklyn:0
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) afghan Restaurants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) afghan Restaurants in Downtown, Brooklyn:0
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) afghan Restaurants in Boerum Hill, Brooklyn:0
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) afghan Restaurants in Prospect Lefferts Gardens, Brooklyn:0
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) afghan Restaurants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) afghan Restaurants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) afghan Restaurants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) afghan Restaurants in Midwood, Brooklyn:0
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) afghan Restaurants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) afghan Restaurants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) afghan Restaurants in East Williamsburg, Brooklyn:0
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) afghan Restaurants in North Side, Brooklyn:0
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) afghan Restaurants in South Side, Brooklyn:0
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) afghan Restaurants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) afghan Restaurants in Fort Hamilton, Brooklyn:0
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) afghan Restaurants in Chinatown, Manhattan:0
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) afghan Restaurants in Washington Heights, Manhattan:0
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) afghan Restaurants in Inwood, Manhattan:0
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) afghan Restaurants in Hamilton Heights, Manhattan:0
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) afghan Restaurants in Manhattanville, Manhattan:0
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) afghan Restaurants in Central Harlem, Manhattan:0
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) afghan Restaurants in East Harlem, Manhattan:0
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) afghan Restaurants in Upper East Side, Manhattan:0
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) afghan Restaurants in Yorkville, Manhattan:0
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) afghan Restaurants in Lenox Hill, Manhattan:1
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) afghan Restaurants in Roosevelt Island, Manhattan:0
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) afghan Restaurants in Upper West Side, Manhattan:0
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) afghan Restaurants in Lincoln Square, Manhattan:0
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) afghan Restaurants in Clinton, Manhattan:0
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) afghan Restaurants in Midtown, Manhattan:0
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) afghan Restaurants in Murray Hill, Manhattan:0
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) afghan Restaurants in Chelsea, Manhattan:0
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) afghan Restaurants in Greenwich Village, Manhattan:0
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) afghan Restaurants in East Village, Manhattan:0
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) afghan Restaurants in Lower East Side, Manhattan:0
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) afghan Restaurants in Tribeca, Manhattan:0
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) afghan Restaurants in Little Italy, Manhattan:0
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) afghan Restaurants in Soho, Manhattan:0
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) afghan Restaurants in West Village, Manhattan:0
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) afghan Restaurants in Manhattan Valley, Manhattan:0
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) afghan Restaurants in Morningside Heights, Manhattan:0
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) afghan Restaurants in Gramercy, Manhattan:0
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) afghan Restaurants in Battery Park City, Manhattan:0
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) afghan Restaurants in Financial District, Manhattan:0
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) afghan Restaurants in Astoria, Queens:0
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) afghan Restaurants in Woodside, Queens:0
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) afghan Restaurants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) afghan Restaurants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) afghan Restaurants in Howard Beach, Queens:0
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) afghan Restaurants in Corona, Queens:0
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) afghan Restaurants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) afghan Restaurants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) afghan Restaurants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) afghan Restaurants in Flushing, Queens:0
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) afghan Restaurants in Long Island City, Queens:0
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) afghan Restaurants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) afghan Restaurants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) afghan Restaurants in Maspeth, Queens:0
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) afghan Restaurants in Ridgewood, Queens:0
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) afghan Restaurants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) afghan Restaurants in Rego Park, Queens:0
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) afghan Restaurants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) afghan Restaurants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) afghan Restaurants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) afghan Restaurants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) afghan Restaurants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) afghan Restaurants in Bayside, Queens:0
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) afghan Restaurants in Auburndale, Queens:0
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) afghan Restaurants in Little Neck, Queens:0
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) afghan Restaurants in Douglaston, Queens:0
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) afghan Restaurants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) afghan Restaurants in Bellerose, Queens:0
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) afghan Restaurants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) afghan Restaurants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) afghan Restaurants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) afghan Restaurants in Jamaica Center, Queens:0
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) afghan Restaurants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) afghan Restaurants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) afghan Restaurants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) afghan Restaurants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) afghan Restaurants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) afghan Restaurants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) afghan Restaurants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) afghan Restaurants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) afghan Restaurants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) afghan Restaurants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) afghan Restaurants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) afghan Restaurants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) afghan Restaurants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) afghan Restaurants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) afghan Restaurants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) afghan Restaurants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) afghan Restaurants in Arverne, Queens:0
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) afghan Restaurants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) afghan Restaurants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) afghan Restaurants in Murray Hill, Queens:0
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) afghan Restaurants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) afghan Restaurants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) afghan Restaurants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) afghan Restaurants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) afghan Restaurants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) afghan Restaurants in Ravenswood, Queens:1
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) afghan Restaurants in Lindenwood, Queens:0
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) afghan Restaurants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) afghan Restaurants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) afghan Restaurants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) afghan Restaurants in Rockaway Park, Queens:0
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) afghan Restaurants in Somerville, Queens:0
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) afghan Restaurants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) afghan Restaurants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) afghan Restaurants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) afghan Restaurants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) afghan Restaurants in St. George, Staten Island:0
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) afghan Restaurants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) afghan Restaurants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) afghan Restaurants in Rosebank, Staten Island:0
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) afghan Restaurants in West Brighton, Staten Island:0
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) afghan Restaurants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) afghan Restaurants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) afghan Restaurants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) afghan Restaurants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) afghan Restaurants in Mariner's Harbor, Staten Island:0
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) afghan Restaurants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) afghan Restaurants in Castleton Corners, Staten Island:0
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 210 / 306 ) afghan Restaurants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 211 / 306 ) afghan Restaurants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 212 / 306 ) afghan Restaurants in New Dorp, Staten Island:0
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 213 / 306 ) afghan Restaurants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 214 / 306 ) afghan Restaurants in Great Kills, Staten Island:0
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 215 / 306 ) afghan Restaurants in Eltingville, Staten Island:0
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 216 / 306 ) afghan Restaurants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 217 / 306 ) afghan Restaurants in Woodrow, Staten Island:0
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 218 / 306 ) afghan Restaurants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 219 / 306 ) afghan Restaurants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 220 / 306 ) afghan Restaurants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 221 / 306 ) afghan Restaurants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 222 / 306 ) afghan Restaurants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 223 / 306 ) afghan Restaurants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 224 / 306 ) afghan Restaurants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 225 / 306 ) afghan Restaurants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 226 / 306 ) afghan Restaurants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 227 / 306 ) afghan Restaurants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 228 / 306 ) afghan Restaurants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 229 / 306 ) afghan Restaurants in Arrochar, Staten Island:0
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 230 / 306 ) afghan Restaurants in Grasmere, Staten Island:0
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 231 / 306 ) afghan Restaurants in Old Town, Staten Island:0
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 232 / 306 ) afghan Restaurants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 233 / 306 ) afghan Restaurants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 234 / 306 ) afghan Restaurants in Grant City, Staten Island:0
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 235 / 306 ) afghan Restaurants in New Dorp Beach, Staten Island:0
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 236 / 306 ) afghan Restaurants in Bay Terrace, Staten Island:0
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 237 / 306 ) afghan Restaurants in Huguenot, Staten Island:0
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 238 / 306 ) afghan Restaurants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 239 / 306 ) afghan Restaurants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 240 / 306 ) afghan Restaurants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 241 / 306 ) afghan Restaurants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 242 / 306 ) afghan Restaurants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 243 / 306 ) afghan Restaurants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 244 / 306 ) afghan Restaurants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 245 / 306 ) afghan Restaurants in Chelsea, Staten Island:0
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 246 / 306 ) afghan Restaurants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 247 / 306 ) afghan Restaurants in Bulls Head, Staten Island:0
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 248 / 306 ) afghan Restaurants in Carnegie Hill, Manhattan:0
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 249 / 306 ) afghan Restaurants in Noho, Manhattan:0
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 250 / 306 ) afghan Restaurants in Civic Center, Manhattan:0
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 251 / 306 ) afghan Restaurants in Midtown South, Manhattan:0
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 252 / 306 ) afghan Restaurants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 253 / 306 ) afghan Restaurants in Shore Acres, Staten Island:0
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 254 / 306 ) afghan Restaurants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 255 / 306 ) afghan Restaurants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 256 / 306 ) afghan Restaurants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 257 / 306 ) afghan Restaurants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 258 / 306 ) afghan Restaurants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 259 / 306 ) afghan Restaurants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 260 / 306 ) afghan Restaurants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 261 / 306 ) afghan Restaurants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 262 / 306 ) afghan Restaurants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 263 / 306 ) afghan Restaurants in Mill Basin, Brooklyn:0
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 264 / 306 ) afghan Restaurants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 265 / 306 ) afghan Restaurants in Utopia, Queens:1
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 266 / 306 ) afghan Restaurants in Pomonok, Queens:0
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 267 / 306 ) afghan Restaurants in Astoria Heights, Queens:0
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 268 / 306 ) afghan Restaurants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) afghan Restaurants in Concourse Village, Bronx:0
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) afghan Restaurants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) afghan Restaurants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) afghan Restaurants in Sutton Place, Manhattan:0
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) afghan Restaurants in Hunters Point, Queens:0
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) afghan Restaurants in Turtle Bay, Manhattan:0
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) afghan Restaurants in Tudor City, Manhattan:0
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) afghan Restaurants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) afghan Restaurants in Flatiron, Manhattan:0
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) afghan Restaurants in Sunnyside Gardens, Queens:0
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) afghan Restaurants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) afghan Restaurants in Fulton Ferry, Brooklyn:0
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) afghan Restaurants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) afghan Restaurants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) afghan Restaurants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) afghan Restaurants in Dumbo, Brooklyn:0
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) afghan Restaurants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) afghan Restaurants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) afghan Restaurants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) afghan Restaurants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) afghan Restaurants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) afghan Restaurants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) afghan Restaurants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) afghan Restaurants in Prince's Bay, Staten Island:0
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) afghan Restaurants in Lighthouse Hill, Staten Island:0
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) afghan Restaurants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) afghan Restaurants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) afghan Restaurants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) afghan Restaurants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) afghan Restaurants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) afghan Restaurants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) afghan Restaurants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) afghan Restaurants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) afghan Restaurants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) afghan Restaurants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) afghan Restaurants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) afghan Restaurants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) afghan Restaurants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %%
#afghan_rest_ny.to_csv('afghan_rest_ny_tocsv1.csv') # Save the information so far to a .csv file due to limited calls on FourSquare
afghan_rest_ny.to_csv('afghan_rest_ny_tocsv1.csv')

# %%
afghan_ny = pd.read_csv('afghan_rest_ny_tocsv1.csv')
afghan_rest_ny.tail()
# Out:
#      Borough Neighborhood                        ID  \
# 0  Manhattan   Lenox Hill  4b22ec71f964a520685024e3
# 1     Queens   Ravenswood  582a1b095f78034bcfb69186
# 2     Queens       Utopia  4b6740aaf964a520fb432be3
#
#                           Name
# 0        Afghan Kebab House II
# 1           Sami's Kebab House
# 2  Bakhter Afghan Halal Kababs

# %%
afghan_rest_ny.shape
# Out:
# (3, 4)

# %% [markdown]
# We got 3 Afghan Restaurants across the New York City.
#
# As we continue our analysis, we see below that Manhattan has one resturant and Queens has two resturant.
#
# Now we will get the ranking of each restaurant for further analysis.

# %%
def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
afghan_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1
for row in afghan_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(afghan_rest_ny),')','processed')
    afghan_rest_stats_ny = afghan_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
afghan_rest_stats_ny.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '6046a0223a222c39eaa88665'}, 'response': {'venue': {'id': '4b22ec71f964a520685024e3', 'name': 'Afghan Kebab House II', 'contact': {'phone': '7188139556', 'formattedPhone': '(718) 813-9556', 'twitter': 'kebabhouseii', 'facebook': '1014488891970711', 'facebookName': 'Afghan Kebab House II'}, 'location': {'address': '1345 2nd Ave', 'crossStreet': 'btw. 70th and 71st St', 'lat': 40.76802139999999, 'lng': -73.95915719999999, 'labeledLatLngs': [{'label': 'display', 'lat': 40.76802139999999, 'lng': -73.95915719999999}], 'postalCode': '10021', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1345 2nd Ave (btw. 70th and 71st St)', 'New York, NY 10021', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/afghan-kebab-house-ii/4b22ec71f964a520685024e3', 'categories': [{'id': '503288ae91d4c4b30a586d67', 'name': 'Afghan Restaurant', 'pluralName': 'Afghan Restaurants', 'shortName': 'Afghan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/afghan_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 11}, 'url': 'http://www.afghankebabhouseny.com/home', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 19, 'groups': [{'type': 'others', 'count': 19, 'items': []}], 'summary': '19 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.8, 'ratingColor': 'C5DE35', 'ratingSignals': 31, 'delivery': {'id': '305339', 'url': 'https://www.seamless.com/menu/afghan-kebob-house-1345-2nd-ave-new-york/305339?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=305339', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/afghan-kebab-house-ii/4b22ec71f964a520685024e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b22ec71f964a520685024e3/device_menu', 'externalUrl': 'http://www.listingextensions.com/f43115baa3/3346738656/menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 23, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 23, 'items': [{'id': '5c0b43d6345cbe002cdb0f57', 'createdAt': 1544242134, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/11073267_iDYAu_mWyq50HYO7En6bermg6VZClOB3AZ69tCpyLHY.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'Food is a beautiful element of every culture, offering health and satisfaction to our days. The chefs at the Afghan Kebab House II cannot wait to create a nourishing, delicious, authentic Middle Eastern meal just for you...', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1260579953, 'tips': {'count': 11, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 11, 'items': [{'id': '52fc33b6498e2b04bc95912c', 'createdAt': 1392260022, 'text': 'Excellent food,no alcohol', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/52fc33b6498e2b04bc95912c', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Mr.', 'lastName': 'X', 'countryCode': 'JP'}, {'firstName': 'İsmail', 'lastName': 'P', 'countryCode': 'TH'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Tory', 'lastName': 'S', 'countryCode': 'US'}, 'authorIntera ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4b22ec71f964a520685024e3  Afghan Kebab House II     19     7.8    11
# ( 1 / 3 ) processed
# {'meta': {'code': 200, 'requestId': '6046a0238675981debab42e7'}, 'response': {'venue': {'id': '582a1b095f78034bcfb69186', 'name': "Sami's Kebab House", 'contact': {'phone': '9178327165', 'formattedPhone': '(917) 832-7165'}, 'location': {'address': '35-57 Crescent St', 'crossStreet': '36th Ave', 'lat': 40.75840750994224, 'lng': -73.93309012994509, 'labeledLatLngs': [{'label': 'display', 'lat': 40.75840750994224, 'lng': -73.93309012994509}], 'postalCode': '11106', 'cc': 'US', 'city': 'Queens', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['35-57 Crescent St (36th Ave)', 'Queens, NY 11106', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/samis-kebab-house/582a1b095f78034bcfb69186', 'categories': [{'id': '503288ae91d4c4b30a586d67', 'name': 'Afghan Restaurant', 'pluralName': 'Afghan Restaurants', 'shortName': 'Afghan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/afghan_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 4}, 'url': 'http://www.samiskababhouse.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 20, 'groups': [{'type': 'others', 'count': 20, 'items': []}], 'summary': '20 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 27, 'delivery': {'id': '403871', 'url': 'https://www.seamless.com/menu/samis-kabob-house-35-57-crescent-st-astoria/403871?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=403871', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.samiskababhouse.com/#anchor-u4465', 'mobileUrl': 'http://www.samiskababhouse.com/#anchor-u4465', 'externalUrl': 'http://www.samiskababhouse.com/#anchor-u4465'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 15, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 15, 'items': [{'id': '5e30e08ed440cd0008f30596', 'createdAt': 1580261518, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42039_yOyLjlkpps-zIQ5HPo8qMpkb8VnjiuEEoYAlOQkAOsE.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1479154441, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5b841a7f031320002c9365c9', 'createdAt': 1535384191, 'text': 'The chicken kabobs were delicious as was the manto dumplings, but the bread was phenomenal! Side sauces served with food are not to be missed!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5b841a7f031320002c9365c9', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Jase', 'lastName': 'E', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2g8CKRD', 'timeZone': 'America/New_York', 'listed': {'count': 37, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 37, 'items': [{'id': '5bba6d28a42362002b99f415', 'name': 'Questions collective New York', 'description': 'Top places to eat near the venue or near the house', 'type': 'others', 'user': {'firstName': 'Joseph', 'lastName': 'A', 'countryCode': 'NL'}, 'editable': False, 'public': True, 'collaborative': True, 'url': '/user/7548664/list/questions-collective-new-york', 'canonicalUrl': 'https://foursquare.com/user/7548664/list/questions-collective-new-york', 'createdAt': 1538944296, 'updatedAt': 1539270357, 'followers': {'count': 3}, 'listItems': ...
#                          ID                Name  Likes  Rating  Tips
# 0  582a1b095f78034bcfb69186  Sami's Kebab House     20     8.1     4
# ( 2 / 3 ) processed
# {'meta': {'code': 200, 'requestId': '6046a023d78f805800fae4bd'}, 'response': {'venue': {'id': '4b6740aaf964a520fb432be3', 'name': 'Bakhter Afghan Halal Kababs', 'contact': {}, 'location': {'address': '68-16 Fresh Meadow Ln', 'lat': 40.73320466046026, 'lng': -73.79464539951913, 'labeledLatLngs': [{'label': 'display', 'lat': 40.73320466046026, 'lng': -73.79464539951913}], 'postalCode': '11365', 'cc': 'US', 'city': 'Fresh Meadows', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['68-16 Fresh Meadow Ln', 'Fresh Meadows, NY 11365', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bakhter-afghan-halal-kababs/4b6740aaf964a520fb432be3', 'categories': [{'id': '503288ae91d4c4b30a586d67', 'name': 'Afghan Restaurant', 'pluralName': 'Afghan Restaurants', 'shortName': 'Afghan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/afghan_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 21}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 23, 'groups': [{'type': 'others', 'count': 23, 'items': []}], 'summary': '23 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.8, 'ratingColor': 'FFC800', 'ratingSignals': 48, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 30, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 30, 'items': [{'id': '51296db9e4b0e836f0327eae', 'createdAt': 1361669561, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4700129_V4CggtOwe7XU0EIJdnPrFh0VCut2naT-safUB3IfHOI.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1265057962, 'tips': {'count': 21, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 21, 'items': [{'id': '4c65e553e75ac928df3ef6da', 'createdAt': 1281746259, 'text': 'Plenty of seating, salad is weak, more fast foodish not so classy', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4c65e553e75ac928df3ef6da', 'lang': 'en', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'firstName': 'Exoticbro', 'countryCode': 'US'}]}], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Azeem', 'lastName': 'K', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/d5ESMH', 'timeZone': 'America/New_York', 'listed': {'count': 14, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 14, 'items': [{'id': '53c640d1498e1a146a82a5f1', 'name': 'The Red Onion', 'description': '', 'type': 'others', 'user': {'firstName': 'Catherine', 'lastName': 'Q', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/82819351/list/the-red-onion', 'canonicalUrl': 'https://foursquare.com/user/82819351/list/the-red-onion', 'createdAt': 1405501649, 'updatedAt': 1415371144, 'photo': {'id': '4fbacd84754a5155d9d18930', 'createdAt': 1337642372, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/u4haCqmMITWokO-JhfMGVO5Ai8DOmERj_1o4Ddav5M0.jpg', 'width': 2560, 'height': 1920, 'visibility': 'public'}, 'followers': {'count': 0}, 'listItems': {'count': 36, 'items': [{'id': 'v4b6740aaf964a520fb432be3', 'createdAt': 1415371144}]}}, {'id': '53d32c67498eb4615bebc7fb', 'name': 'Foursquare And Seven Years Ago', 'description': '', 'type': 'others', 'user': {'firstName': 'Catherine', 'lastName': 'Q', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/82819351/list/foursquare-and-seven-years-ago', 'canonicalUrl': 'https://foursquare.com/user/82819351/list/foursquare-and-seven-years-ago', 'createdAt': 1406348391, 'updatedAt': 1415371160, 'followers': {'count': 0}, 'lis ...
#                          ID                         Name  Likes  Rating  Tips
# 0  4b6740aaf964a520fb432be3  Bakhter Afghan Halal Kababs     23     6.8    21
# ( 3 / 3 ) processed
#      Borough Neighborhood                        ID  \
# 0  Manhattan   Lenox Hill  4b22ec71f964a520685024e3
# 1     Queens   Ravenswood  582a1b095f78034bcfb69186
# 2     Queens       Utopia  4b6740aaf964a520fb432be3
#
#                           Name Likes  Rating Tips
# 0        Afghan Kebab House II    19     7.8   11
# 1           Sami's Kebab House    20     8.1    4
# 2  Bakhter Afghan Halal Kababs    23     6.8   21

# %%
afghan_rest_stats_ny.to_csv('afghan_rest_stats_ny_csv.csv') # As I move through this project I continue to save data to a .csv file
afghan_rest_stats_ny.shape
# Out:
# (3, 7)

# %% [markdown]
# We got statistics for all 3 Afghan Restaurants in New York city.
#
# Let's check what values we have in our DataFrame

# %%
afghan_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       3 non-null      object
#  1   Neighborhood  3 non-null      object
#  2   ID            3 non-null      object
#  3   Name          3 non-null      object
#  4   Likes         3 non-null      object
#  5   Rating        3 non-null      float64
#  6   Tips          3 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 296.0+ bytes

# %% [markdown]
# We see that the values like Likes, Tips are string values. We would need to convert them into float for further analysis

# %%
afghan_rest_stats_ny['Likes'] = afghan_rest_stats_ny['Likes'].astype('float64')
afghan_rest_stats_ny['Tips'] = afghan_rest_stats_ny['Tips'].astype('float64')
afghan_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       3 non-null      object
#  1   Neighborhood  3 non-null      object
#  2   ID            3 non-null      object
#  3   Name          3 non-null      object
#  4   Likes         3 non-null      float64
#  5   Rating        3 non-null      float64
#  6   Tips          3 non-null      float64
# dtypes: float64(3), object(4)
# memory usage: 296.0+ bytes

# %%
afghan_rest_stats_ny.describe()
# Out:
#            Likes    Rating       Tips
# count   3.000000  3.000000   3.000000
# mean   20.666667  7.566667  12.000000
# std     2.081666  0.680686   8.544004
# min    19.000000  6.800000   4.000000
# 25%    19.500000  7.300000   7.500000
# 50%    20.000000  7.800000  11.000000
# 75%    21.500000  7.950000  16.000000
# max    23.000000  8.100000  21.000000

# %%
# Resturant with maximum Like
afghan_rest_stats_ny.iloc[afghan_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                              Queens
# Neighborhood                         Utopia
# ID                 4b6740aaf964a520fb432be3
# Name            Bakhter Afghan Halal Kababs
# Likes                                    23
# Rating                                  6.8
# Tips                                     21
# Name: 2, dtype: object

# %%
# Resturant with maximum Ratings
afghan_rest_stats_ny.iloc[afghan_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                           Queens
# Neighborhood                  Ravenswood
# ID              582a1b095f78034bcfb69186
# Name                  Sami's Kebab House
# Likes                                 20
# Rating                               8.1
# Tips                                   4
# Name: 1, dtype: object

# %%
# Resturant with maximum Tips
afghan_rest_stats_ny.iloc[afghan_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                              Queens
# Neighborhood                         Utopia
# ID                 4b6740aaf964a520fb432be3
# Name            Bakhter Afghan Halal Kababs
# Likes                                    23
# Rating                                  6.8
# Tips                                     21
# Name: 2, dtype: object

# %%
ny_neighborhood_stats=afghan_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#   Neighborhood  Average Rating
# 1   Ravenswood             8.1
# 0   Lenox Hill             7.8
# 2       Utopia             6.8

# %% [markdown]
# Above are the top neighborhoods with the highest average ratings of Afghan restaurants.

# %%
ny_borough_stats=afghan_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#      Borough  Average Rating
# 0  Manhattan            7.80
# 1     Queens            7.45

# %% [markdown]
# Similarly these are the average ratings of Afghan Restaurants for each Borough

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# From the data of the Foursquare API, we can see that there are only three afghani resturants in New York City, which is very unusual. I think the data is not that much updated or the afghani resturants are not group accordingly. The afghani resturants might be mistaken with Irani/Persian resturant as these two couisins are much similar. These could be another project to include the Afghani and Irani resturant together and see their ratings and likes. For this project, we will just consider the afghani resturant for further data analysis and result/conclusion.

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Average rating of afghan Restaurants for each Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
afghan_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar', color=clr)
plt.legend()
plt.show()

# %% [markdown]
# We will join this Dataset to original New York data to get longitude and latitude

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,ny_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats
# Out:
#      Borough Neighborhood   Latitude  Longitude  Average Rating
# 0  Manhattan   Lenox Hill  40.768113 -73.958860             7.8
# 1     Queens   Ravenswood  40.761705 -73.931575             8.1
# 2     Queens       Utopia  40.733500 -73.796717             6.8

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
# instantiate a feature group for the ratings in the dataframe
rating = folium.map.FeatureGroup()

# loop through the ratings and add each to the neighborhood feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    rating.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add ratings to map
ny_map.add_child(rating)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5.Results / Conclusion

# %% [markdown]
# From the figure above, we can see that the Manhattan has one afghani resturant and Queens have two afghani resturants. So there is very good opportunity to open an afghani resturant in neighborhood other than these two. From these information, we cannot conclude much where to open a new afghani resturants which will give us the most profits. Based on the rating, likes and tips, I would say that the afghani resturant in Queens neighborhood and in Utopia borough is the best one, that I would visit. I would not open a new resturant near that one. For further evaluation of opening a afghani resturant one should take consideration of the population data of the afghani origin people living in New York City. If we can combine that data with the data above then we can also make a very good decision to open a afghani resturant where the population of the Afghani people are more and there might not be a afghani resturant near to them or may have not good rating and likes. As a final note, all of the above analyses is depended on the adequacy and accuracy of Four Square data. A more comprehensive analysis and future work would need to incorporate data from other external databases.
#
# Finally, to conclude this project, we have got a small glimpse of how a real-life Data science project looks like. I have used some frequently used python libraries to handle JSON file, plotting graphs, and other exploratory data analysis. Use Foursquare API to major boroughs of New York City and their neighborhoods.The potential for this kind of analysis in a real-life business problem is discussed in great detail. I would like to thank you Coursera and IBM for a such a great course and specilization certificate.
